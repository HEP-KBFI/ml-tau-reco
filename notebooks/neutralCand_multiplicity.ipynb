# %%
import vector
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
data = []
data_qcd = []
for f in glob.glob('/local/snandan/HPS_correctpath/HPS/ZH_Htautau//*parquet')[:100]:
    data.append(ak.Array(ak.from_parquet(f).tolist()))
for f in glob.glob('/local/snandan/HPS_correctpath/HPS/QCD/*parquet')[:100]:
    data_qcd.append(ak.Array((ak.from_parquet(f).tolist())))
data = ak.concatenate(data)
data_qcd = ak.concatenate(data_qcd)
print('data loaded')
# Out:
# data loaded

# %%
zh_pt = data.tau_neutralHadron_pt
#print(ak.any(zh_pt==0))
a,b,c=plt.hist(
        ak.flatten(data.tau_neutralHadron_pt), histtype='step', label='ZH_tautau, neutral hadron pt with no cut', lw=2, bins=100,\
        range=(0,50),
        alpha=1, stacked=True, density=True, log=True
    )
a,b,c=plt.hist(
        ak.flatten(data_qcd.tau_neutralHadron_pt), histtype='step', label='QCD, neutral hadron pt with no cut', lw=2,\
        bins=100, range=(0,50),
       alpha=1, stacked=True, density=True, log=True
    )
plt.legend()

# %%
a,b,c=plt.hist(
        data.tau_nneutralHadron, histtype='step', label='ZH_tautau, neutral hadron multiplicity with no cut ', lw=2, bins=11,\
        range=(-0.5,10.5),
        alpha=1, stacked=True, density=True, log=True)
a,b,c=plt.hist(
        data_qcd.tau_nneutralHadron, histtype='step', label='QCD, neutral hadron multiplicity with no cut', lw=2, bins=11,\
        range=(-0.5,10.5),
        alpha=1, stacked=True, density=True, log=True)
plt.legend()

# %%
a,b,c=plt.hist(
        data.tauNeutralHadronIso_dR0p5, histtype='step', label='ZH_tautau, neutral hadron sumpt within dR_0p5 with no cut', lw=2, bins=100,\
        range=(0,20),
        alpha=1, stacked=True, density=True, log=True)
a,b,c=plt.hist(
       data_qcd.tauNeutralHadronIso_dR0p5, histtype='step', label='QCD, neutral hadron sumpt within dr_0p5 with no cut', lw=2, bins=100,\
        range=(0,20),
        alpha=1, stacked=True, density=True, log=True)
plt.legend()

# %%
a,b,c=plt.hist(
        data.tau_nneutralHadron_wpt_2, histtype='step', label='ZH_tautau, neutral hadron multiplicity with pt>2', lw=2, bins=11,\
        range=(-0.5,10.5),
        alpha=1, stacked=True, density=True, log=True)
a,b,c=plt.hist(
        data_qcd.tau_nneutralHadron_wpt_2, histtype='step', label='QCD, neutral hadron multiplicity with pt>2', lw=2, bins=11,\
        range=(-0.5,10.5),
        alpha=1, stacked=True, density=True, log=True)
plt.legend()

# %%
a,b,c=plt.hist(
        data.tau_nneutralHadron_wpt_5, histtype='step', label='ZH_tautau,neutral hadron multiplicity with pt>5', lw=2, bins=11,\
        range=(-0.5,10.5),
        alpha=1, stacked=True, density=True, log=True)
a,b,c=plt.hist(
        data_qcd.tau_nneutralHadron_wpt_5, histtype='step', label='QCD,neutral hadron multiplicity with pt>5', lw=2, bins=11,\
        range=(-0.5,10.5),
        alpha=1, stacked=True, density=True, log=True)
plt.legend()

# %%
a,b,c=plt.hist(
        data.tau_nneutralHadron_wpt_10, histtype='step', label='ZH_tautau,neutral hadron multiplicity with pt>10', lw=2, bins=11,\
        range=(-0.5,10.5),
        alpha=1, stacked=True, density=True, log=True)
a,b,c=plt.hist(
        data_qcd.tau_nneutralHadron_wpt_2, histtype='step', label='QCD,neutral hadron multiplicity with pt>10', lw=2, bins=11,\
        range=(-0.5,10.5),
        alpha=1, stacked=True, density=True, log=True)
plt.legend()

# %%
a,b,c=plt.hist(
        data.taucombinedIso_dR0p5, histtype='step', label='ZH_tautau,taucombinedIso_dR0p5', lw=2, bins=11,\
        range=(-0.5,10.5),
        alpha=1, stacked=True, density=True, log=True)
a,b,c=plt.hist(
        data_qcd.taucombinedIso_dR0p5, histtype='step', label='QCD,taucombinedIso_dR0p5', lw=2, bins=11,\
        range=(-0.5,10.5),
        alpha=1, stacked=True, density=True, log=True)
plt.legend()
